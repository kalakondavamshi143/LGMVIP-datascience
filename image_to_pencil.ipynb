# %% [markdown]
# <a href="https://colab.research.google.com/github/kalakondavamshi143/LGMVIP-datascience/blob/main/image_to_pencil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from skimage import io

# %%
image = io.imread("4567.png")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200 at 0x7FE732508B10>

# %%
gray_filter = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_filter)
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7FE73FB0AB90>

# %%
inverted_filter = cv2.bitwise_not(gray_filter)
cv2_imshow(inverted_filter)
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7FE71D74BC10>

# %%
image_smoothing = cv2.GaussianBlur(inverted_filter, (21, 21), sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7FE71D74B790>

# %%
def pencil_sketch(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch = pencil_sketch(gray_filter, image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1600x1200 at 0x7FE71D74FD90>
